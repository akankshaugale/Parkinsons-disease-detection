# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # import data from csv file

# %%
df = pd.read_csv('parkinsons.data',delim_whitespace = False)
df.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %% [markdown]
# # EDA

# %%
df.tail()
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 190  phon_R01_S50_2      174.188       230.978        94.261         0.00459
# 191  phon_R01_S50_3      209.516       253.017        89.488         0.00564
# 192  phon_R01_S50_4      174.688       240.005        74.287         0.01360
# 193  phon_R01_S50_5      198.764       396.961        74.904         0.00740
# 194  phon_R01_S50_6      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 190           0.00003   0.00263   0.00259     0.00790       0.04087  ...
# 191           0.00003   0.00331   0.00292     0.00994       0.02751  ...
# 192           0.00008   0.00624   0.00564     0.01873       0.02308  ...
# 193           0.00004   0.00370   0.00390     0.01109       0.02296  ...
# 194           0.00003   0.00295   0.00317     0.00885       0.01884  ...
#
# ...

# %% [markdown]
# #### These are the last 5 instance of the Paarkinsons data which contains 24 columns.

# %%
df.shape
# Out:
# (195, 24)

# %%
df.size
# Out:
# 4680

# %% [markdown]
# #### After finding subsets of a data we move further to find shape and size of the dataset. from this we got that the shape of the data is (195 (instances),24(columns))

# %%
df.drop('name',axis=1,inplace=True)
df.head()
# Out:
#    MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  MDVP:Jitter(Abs)  \
# 0      119.992       157.302        74.997         0.00784           0.00007
# 1      122.400       148.650       113.819         0.00968           0.00008
# 2      116.682       131.111       111.555         0.01050           0.00009
# 3      116.676       137.871       111.366         0.00997           0.00009
# 4      116.014       141.781       110.655         0.01284           0.00011
#
#    MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  MDVP:Shimmer(dB)  ...  \
# 0   0.00370   0.00554     0.01109       0.04374             0.426  ...
# 1   0.00465   0.00696     0.01394       0.06134             0.626  ...
# 2   0.00544   0.00781     0.01633       0.05233             0.482  ...
# 3   0.00502   0.00698     0.01505       0.05492             0.517  ...
# 4   0.00655   0.00908     0.01966       0.06425             0.584  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %% [markdown]
# # info of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   MDVP:Fo(Hz)       195 non-null    float64
#  1   MDVP:Fhi(Hz)      195 non-null    float64
#  2   MDVP:Flo(Hz)      195 non-null    float64
#  3   MDVP:Jitter(%)    195 non-null    float64
#  4   MDVP:Jitter(Abs)  195 non-null    float64
#  5   MDVP:RAP          195 non-null    float64
#  6   MDVP:PPQ          195 non-null    float64
#  7   Jitter:DDP        195 non-null    float64
#  8   MDVP:Shimmer      195 non-null    float64
#  9   MDVP:Shimmer(dB)  195 non-null    float64
#  10  Shimmer:APQ3      195 non-null    float64
#  11  Shimmer:APQ5      195 non-null    float64
#  12  MDVP:APQ          195 non-null    float64
#  13  Shimmer:DDA       195 non-null    float64
#  14  NHR               195 non-null    float64
#  15  HNR               195 non-null    float64
# ...

# %% [markdown]
# #### Further we applied the method .info() to understand more about the data
# ##### From df.info() we got that their are 195 instances ranging from 0 to 194. the dataset contain 23 columns ranging from 0 to 22 having data type 'float64' and 'int64' res

# %%
df.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %% [markdown]
# # Unique values

# %%
df.nunique()
# Out:
# MDVP:Fo(Hz)         195
# MDVP:Fhi(Hz)        195
# MDVP:Flo(Hz)        195
# MDVP:Jitter(%)      173
# MDVP:Jitter(Abs)     19
# MDVP:RAP            155
# MDVP:PPQ            165
# Jitter:DDP          180
# MDVP:Shimmer        188
# MDVP:Shimmer(dB)    149
# Shimmer:APQ3        184
# Shimmer:APQ5        189
# MDVP:APQ            189
# Shimmer:DDA         189
# NHR                 185
# HNR                 195
# status                2
# RPDE                195
# DFA                 195
# spread1             195
# spread2             194
# D2                  195
# PPE                 195
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Univariate Analysis

# %%
plt.figure(figsize = (15,12))
sns.lineplot(data = df)
# Out:
# <AxesSubplot:>

# %%
df['status'].value_counts()
# Out:
# 1    147
# 0     48
# Name: status, dtype: int64

# %%
df.groupby('status').mean()
# Out:
#         MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# status
# 0        181.937771    223.636750    145.207292        0.003866
# 1        145.180762    188.441463    106.893558        0.006989
#
#         MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# status
# 0               0.000023  0.001925  0.002056    0.005776      0.017615
# 1               0.000051  0.003757  0.003900    0.011273      0.033658
#
#         MDVP:Shimmer(dB)  ...  MDVP:APQ  Shimmer:DDA       NHR        HNR  \
# status                    ...
# 0               0.162958  ...  0.013305     0.028511  0.011483  24.678750
# 1               0.321204  ...  0.027600     0.053027  0.029211  20.974048
#
#             RPDE       DFA   spread1   spread2        D2       PPE
# status
# 0       0.442552  0.695716 -6.759264  0.160292  2.154491  0.123017
# 1       0.516816  0.725408 -5.333420  0.248133  2.456058  0.233828
#
# [2 rows x 22 columns]

# %% [markdown]
# # Bivariate Analysis

# %%
sns.boxplot(df['DFA'],orient = 'h');

# %%
sns.boxplot(df['MDVP:Fhi(Hz)'],orient = 'h');
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
for colname,colvals in df.iteritems():
    if df[colname].dtype!=object and colname!='status':
        Q1=df[colname].quantile(q=0.25)
        Q3=df[colname].quantile(q=0.75)
        IQR=Q3-Q1
        low=Q1-(1.5*IQR)
        up=Q3+(1.5*IQR)
        df.loc[(df[colname]<low) | (df[colname]>up) ,colname]=df[colname].median()
    else:
        continue

# %%
plt.figure(figsize = (12,12))
dd1 = df.drop(['status'],axis =1)
sns.boxplot(data = dd1,orient = 'h')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Selecting Feature and Target columns

# %%
X = df.drop('status',axis=1)
y = df['status']

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.8,random_state = 2)

# %% [markdown]
# * Train/Test Split involves splitting the dataset into training and testing sets that are mutually exclusive. After which, you train with the training set and test with the testing set. This will provide a more accurate evaluation on out-of-sample accuracy because the testing dataset is not part of the dataset that have been used to train the model. Therefore, it gives us a better understanding of how well our model generalizes on new data.

# %% [markdown]
# ### Standardization

# %%
scaler = StandardScaler()
X_train= scaler.fit_transform(X_train,y_train)
X_test = scaler.fit_transform(X_test,y_test)

# %% [markdown]
# ### Creating Model Using Support Vecrtor Machine with the help of SkLearn Library

# %%
from sklearn import svm
model = svm.SVC(kernel = 'linear')

# %%
model.fit(X_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

from sklearn.metrics import accuracy_score

# %%
training_accuracy = accuracy_score(y_train,y_train_pred)
testing_accuracy = accuracy_score(y_test,y_test_pred)

# %%
print('training accuracy : ',training_accuracy)
print('testing accuracy : ',testing_accuracy)
# Out:
# training accuracy :  0.9166666666666666
# testing accuracy :  0.8205128205128205

# %%
from sklearn.model_selection import GridSearchCV
  
# defining parameter range
param_grid = {'C': [0.1, 1, 10, 100, 1000], 
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'kernel': ['rbf','linear']} 
  
grid = GridSearchCV(svm.SVC(), param_grid, refit = True, verbose = 3)
  
# fitting the model for grid search
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.750 total time=   0.0s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.742 total time=   0.0s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.742 total time=   0.0s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.742 total time=   0.0s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.742 total time=   0.0s
# [CV 1/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.812 total time=   0.0s
# [CV 2/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.839 total time=   0.0s
# [CV 3/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.839 total time=   0.0s
# [CV 4/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.774 total time=   0.0s
# [CV 5/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.710 total time=   0.0s
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.750 total time=   0.0s
# ...

# %%
# print best parameter after tuning
print(grid.best_params_)
# Out:
# {'C': 100, 'gamma': 0.01, 'kernel': 'rbf'}

# %%
# print how our model looks after hyper-parameter tuning
print(grid.best_estimator_)
# Out:
# SVC(C=100, gamma=0.01)

# %%
grid_predictions = grid.predict(X_test)
from sklearn.metrics import classification_report, confusion_matrix
# print classification report
print(classification_report(y_test, grid_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.75      0.67         8
#            1       0.93      0.87      0.90        31
#
#     accuracy                           0.85        39
#    macro avg       0.77      0.81      0.78        39
# weighted avg       0.86      0.85      0.85        39

# %% [markdown]
# ## predicting With New data

# %%
new_input2 = [174.68800,240.00500,74.28700,0.01360,0.00008,0.00624,0.00564,0.01873,0.02308,0.25600,0.01268,0.01365,0.01667,0.03804,0.10715,17.88300,0.407567,0.655683,-6.787197,0.158453,2.679772,0.131728]
new_input_as_array = np.asarray(new_input2)

reshaped_data = new_input_as_array.reshape(1,-1)

scaled_data =scaler.transform(reshaped_data) 

prediction = model.predict(scaled_data)
print(prediction)

if (prediction[0] == 0):
    print('The person does not have parkinson')
else :
    print('the person have parkinson')
# Out:
# [1]
# the person have parkinson
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
import warnings

new_input = [101.67600,115.87100,100.36600,0.00777,0.00009,0.00502,0.00698,0.01505,0.05492,0.62700,0.02924,0.04005,0.03772,0.08771,0.01353,10.64400,0.434969,0.819235,-4.117501,0.334147,2.405554,0.368975]

new_input_as_array = np.asarray(new_input)

reshaped_data = new_input_as_array.reshape(1,-1)

scaled_data =scaler.transform(reshaped_data) 

prediction = model.predict(scaled_data)
print(prediction)

if (prediction[0] == 0):
    print('The perso does not have parkinson')
else :
    print('the person have parkinson')
# Out:
# [1]
# the person have parkinson
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %% [markdown]
# * From the above model we can predict that the person have Parkinson's disease or not
